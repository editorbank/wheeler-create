# %%
import ipywidgets as widgets
from IPython.display import  display

# %%
a = widgets.FloatText(value = '77.70')
b = widgets.FloatSlider()
display(a,b)

mylink = widgets.jslink((a, 'value'), (b, 'value'))
# Out:
# FloatText(value=77.7)
# FloatSlider(value=0.0)
